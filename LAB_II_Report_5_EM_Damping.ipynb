# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %% [markdown]
# PART A

# %%
(at1,ay1,av1)=np.loadtxt("../content/a50.csv", delimiter=",", unpack=True)
(at2,ay2,av2)=np.loadtxt("../content/a100.csv", delimiter=",", unpack=True)
(at3,ay3,av3)=np.loadtxt("../content/a150.csv", delimiter=",", unpack=True)
(at4,ay4,av4)=np.loadtxt("../content/a200.csv", delimiter=",", unpack=True)
(at5,ay5,av5)=np.loadtxt("../content/a250.csv", delimiter=",", unpack=True)
(at6,ay6,av6)=np.loadtxt("../content/a300.csv", delimiter=",", unpack=True)
(at7,ay7,av7)=np.loadtxt("../content/a350.csv", delimiter=",", unpack=True)

# %%
y_error_a = 0
x_error_a = 0
plt.scatter(at1,ay1)
plt.plot(at1,ay1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at1,ay1, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()
am1,ac1 = np.polyfit(at1,av1, 1)
print('am1=', am1, 'ac1=', ac1)


plt.scatter(at2,ay2)
plt.plot(at2,ay2)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at2,ay2, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am2,ac2 = np.polyfit(at2,av2, 1)
print('am2=', am2, 'ac2=', ac2)


plt.scatter(at3,ay3)
plt.plot(at3,ay3)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at3,ay3, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am3,ac3 = np.polyfit(at3,av3, 1)
print('am3=', am3, 'ac3=', ac3)

plt.scatter(at4,ay4)
plt.plot(at4,ay4)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at4,ay4, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am4,ac4 = np.polyfit(at4,av4, 1)
print('am4=', am4, 'ac4=', ac4)

plt.scatter(at5,ay5)
plt.plot(at5,ay5)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at5,ay5, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am5,ac5 = np.polyfit(at5,av5, 1)
print('am5=', am5, 'ac5=', ac5)

plt.scatter(at6,ay6)
plt.plot(at6,ay6)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at6,ay6, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am6,ac6 = np.polyfit(at6,av6, 1)
print('am6=', am6, 'ac6=', ac6)

plt.scatter(at7,ay7)
plt.plot(at7,ay7)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(at7,ay7, yerr=y_error_a, xerr=x_error_a, fmt='o')
plt.show()

am7,ac7 = np.polyfit(at7,av7, 1)
print('am7=', am7, 'ac7=', ac7)
# Out:
# am1= -0.004870529326282906 ac1= -0.01633455052674762
# am2= -0.009210028834393839 ac2= -0.02414198975022897
# am3= -0.015106045805806038 ac3= -0.018093305181731672
# am4= -0.01981912465821988 ac4= -0.03753198502455224
# am5= -0.025087060001260965 ac5= -0.0336728140520232
# am6= -0.030797559710807467 ac6= -0.030300490789711452
# am7= -0.03622766286997333 ac7= -0.023655801631911538

# %%
M = np.array([50,100,150,200,250,300,350])
#A = np.array([am1,am2,am3,am4,am5,am6,am7])
A =np.array([-0.00487,-0.0101,-0.01510,-0.019989,-0.025087,-0.030797,-0.036227])
plt.scatter(M,A)
plt.plot(M,A)
plt.xlabel('Mass (g)')
plt.ylabel('Acceleration (m/s2)')
plt.show()
am,ac = np.polyfit(M,A, 1)
print('Slope=', am, 'Intercept=', ac)
# Out:
# Slope= -0.00010389428571428575 Intercept= 0.00046885714285714055

# %% [markdown]
# PART B

# %%
(bt1,by1)=np.loadtxt("../content/b50.csv", delimiter=",", unpack=True)
(bt2,by2)=np.loadtxt("../content/b100.csv", delimiter=",", unpack=True)
(bt3,by3)=np.loadtxt("../content/b150.csv", delimiter=",", unpack=True)
(bt4,by4)=np.loadtxt("../content/b200.csv", delimiter=",", unpack=True)
(bt5,by5)=np.loadtxt("../content/b250.csv", delimiter=",", unpack=True)
(bt6,by6)=np.loadtxt("../content/b300.csv", delimiter=",", unpack=True)
(bt7,by7)=np.loadtxt("../content/b350.csv", delimiter=",", unpack=True)

# %%
y_error = 0
x_error = 0
plt.scatter(bt1,by1)
plt.plot(bt1,by1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt1,by1, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm1,bc1 = np.polyfit(bt1,by1, 1)
print('bm1=', bm1, 'bc1=', bc1)
plt.scatter(bt2,by2)
plt.plot(bt2,by2)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt2,by2, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm2,bc2 = np.polyfit(bt2,by2, 1)
print('bm2=', bm2, 'bc2=', bc2)
plt.scatter(bt3,by3)
plt.plot(bt3,by3)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt3,by3, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm3,bc3 = np.polyfit(bt3,by3, 1)
print('bm3=', bm3, 'bc3=', bc3)
plt.scatter(bt4,by4)
plt.plot(bt4,by4)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt4,by4, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm4,bc4 = np.polyfit(bt4,by4, 1)
print('bm4=', bm4, 'bc4=', bc4)
plt.scatter(bt5,by5)
plt.plot(bt5,by5)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt5,by5, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm5,bc5 = np.polyfit(bt5,by5, 1)
print('bm5=', bm5, 'bc5=', bc5)
plt.scatter(bt6,by6)
plt.plot(bt6,by6)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt6,by6, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm6,bc6 = np.polyfit(bt6,by6, 1)
print('bm6=', bm6, 'bc6=', bc6)
plt.scatter(bt7,by7)
plt.plot(bt7,by7)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(bt7,by7, yerr=y_error, xerr=x_error, fmt='o')
plt.show()
bm7,bc7 = np.polyfit(bt7,by7, 1)
print('bm7=', bm7, 'bc7=', bc7)
# Out:
# bm1= -0.01116757771271379 bc1= -0.006438795396200002
# bm2= -0.02389481318173186 bc2= 0.02318699224066405
# bm3= -0.036253729071392175 bc3= 0.05958032733543843
# bm4= -0.04775870954712534 bc4= 0.06722460569335488
# bm5= -0.059296071138012295 bc5= 0.08033632187282426
# bm6= -0.07098252725471135 bc6= 0.0855478362194131
# bm7= -0.08152517211069778 bc7= 0.08264994773631489

# %%
tv = np.array([-bm1,-bm2,-bm3,-bm4,-bm5,-bm6,-bm7]) # entire graph
tv2 = np.array([0.0107, 0.0228, 0.0356, 0.0476, 0.0602, 0.0728, 0.0842]) #only terminal velocity part
plt.scatter(M,tv)
plt.plot(M,tv)
plt.xlabel('Mass (g)')
plt.ylabel('Terminal Velocity (m/s)')
plt.show()
bm,bc = np.polyfit(M,tv, 1)
print('Slope=', bm, 'Intercept=', bc)

plt.scatter(M,tv2)
plt.plot(M,tv2)
plt.xlabel('Mass (g)')
plt.ylabel('Terminal Velocity (m/s)')
plt.show()
bm2,bc2 = np.polyfit(M,tv2, 1)
print('Slope=', bm2, 'Intercept=', bc2)
# Out:
# Slope= 0.00023449325243323648 Intercept= 0.0003697209442647951
# Slope= 0.0002465000000000001 Intercept= -0.0015999999999999712

# %% [markdown]
# PART C

# %%
s = np.array([1.4,1.9,2.4,2.9,3.4,4.4,5.4])
B = np.array([97,52,31,19,13,7,4])

# %%
plt.scatter(s, B)
plt.plot(s,B)
plt.xlabel('Separation (cm)')
plt.ylabel('Magnetic Field (Gauss)')
plt.show()

# %%
(ct1,cy1)=np.loadtxt("../content/c1.csv", delimiter=",", unpack=True)
(ct2,cy2)=np.loadtxt("../content/c2.csv", delimiter=",", unpack=True)
(ct3,cy3)=np.loadtxt("../content/c3.csv", delimiter=",", unpack=True)
(ct4,cy4)=np.loadtxt("../content/c4.csv", delimiter=",", unpack=True)
(ct5,cy5)=np.loadtxt("../content/c5.csv", delimiter=",", unpack=True)
(ct6,cy6)=np.loadtxt("../content/c6.csv", delimiter=",", unpack=True)
(ct7,cy7)=np.loadtxt("../content/c7.csv", delimiter=",", unpack=True)

# %%
y_error_c = 0
x_error_c = 0
plt.scatter(ct1,cy1)
plt.plot(ct1,cy1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct1,cy1, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm1,cc1 = np.polyfit(ct1,cy1, 1)
print('cm1=', cm1, 'cc1=', cc1)

plt.scatter(ct2,cy2)
plt.plot(ct2,cy2)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct2,cy2, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm2,cc2 = np.polyfit(ct2,cy2, 1)
print('cm2=', cm2, 'cc2=', cc2)

plt.scatter(ct3,cy3)
plt.plot(ct3,cy3)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct3,cy3, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm3,cc3 = np.polyfit(ct3,cy3, 1)
print('cm3=', cm3, 'cc3=', cc3)

plt.scatter(ct4,cy4)
plt.plot(ct4,cy4)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct4,cy4, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm4,cc4 = np.polyfit(ct4,cy4, 1)
print('cm4=', cm4, 'cc4=', cc4)

plt.scatter(ct5,cy5)
plt.plot(ct5,cy5)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct5,cy5, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm5,cc5 = np.polyfit(ct5,cy5, 1)
print('cm5=', cm5, 'cc5=', cc5)

plt.scatter(ct6,cy6)
plt.plot(ct6,cy6)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct6,cy6, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm6,cc6 = np.polyfit(ct6,cy6, 1)
print('cm6=', cm6, 'cc6=', cc6)

plt.scatter(ct7,cy7)
plt.plot(ct7,cy7)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.errorbar(ct7,cy7, yerr=y_error_c, xerr=x_error_c, fmt='o')
plt.show()
cm7,cc7 = np.polyfit(ct7,cy7, 1)
print('cm7=', cm7, 'cc7=', cc7)
# Out:
# cm1= -0.02613256740981906 cc1= 0.25970513196350453
# cm2= -0.052568090184068696 cc2= 0.3503877230532145
# cm3= -0.6664080367162324 cc3= 3.8491845851846924
# cm4= -0.7198046116530004 cc4= 1.5509235002910993
# cm5= -0.07480634241221058 cc5= 0.14592192729861894
# cm6= -0.07830654503110736 cc6= 0.15217770505779876
# cm7= -0.0794196740331172 cc7= 0.15040746874706215

# %%
B = np.array([97,52,31,19,13,7,4])
V = np.array([0.0002, 0.0021,0.0043,0.0118,0.0269,0.0687,0.1247])
plt.scatter(B, V)
plt.plot(B,V)
plt.xlabel('Magnetic Field (Gauss)')
plt.ylabel('Terminal Velocity (m/s)')
plt.show()

# %%
V = np.array([0.0002, 0.0021,0.0043,0.0118,0.0269,0.0687,0.1247])
s = np.array([1.4,1.9,2.4,2.9,3.4,4.4,5.4])
s2= s/100
plt.scatter(s2, V)
plt.plot(s2,V)
plt.xlabel('Separation (m)')
plt.ylabel('Terminal Velocity (m/s)')
plt.show()
