# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import scipy
from scipy.optimize import curve_fit
from scipy.stats import norm

# %% [markdown]
# **SQUASH BALL**

# %%
(st1,sy1,sv1)= np.loadtxt("../content/SA1.csv", delimiter=",", unpack=True)

plt.scatter(st1,sy1)
sa1,sb1, sc1 = np.polyfit(st1,sy1, 2)
sy1_n = [sa1*(i**2) + sb1*i +sc1 for i in st1]
plt.plot(st1, sy1_n,"r", label=r"Eq. of Parabola: $y = -5.1484 t^2 - 0.8598 t + 0.0008$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa1=', sa1, 'sb1=', sb1, 'sc1=', sc1)

plt.scatter(st1,sv1)
sm1,sk1 = np.polyfit(st1,sv1, 1)
sv1_n = [sm1*i + sk1 for i in st1]
plt.plot(st1, sv1_n, "r", label=r"Eq. of Line: $v = -9.9768 t -0.9255$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm1=', sm1, 'sk1=', sk1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-9cf9fd5d6901> in <module>
# ----> 1 (st1,sy1,sv1)= np.loadtxt("../content/SA1.csv", delimiter=",", unpack=True)
#       2
#       3 plt.scatter(st1,sy1)
#       4 sa1,sb1, sc1 = np.polyfit(st1,sy1, 2)
#       5 sy1_n = [sa1*(i**2) + sb1*i +sc1 for i in st1]
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068             fencoding = getattr(fh, 'encoding', 'latin1')
#    1069             fh = iter(fh)
#
# ...

# %%
(st2,sy2,sv2)= np.loadtxt("../content/SA2.csv", delimiter=",", unpack=True)

plt.scatter(st2,sy2)
sa2,sb2, sc2 = np.polyfit(st2,sy2, 2)
sy2_n = [sa2*(i**2) + sb2*i +sc2 for i in st2]
plt.plot(st2, sy2_n,"r", label=r"Eq. of Parabola: $y = -5.3022 t^2 - 1.1881 t -0.0019$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa2=', sa2, 'sb2=', sb2, 'sc2=', sc2)

plt.scatter(st2,sv2)
sm2,sk2 = np.polyfit(st2,sv2, 1)
sv2_n = [sm2*i + sk2 for i in st2]
plt.plot(st2, sv2_n, "r", label=r"Eq. of Line: $v = -10.5162 t -1.2075$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm2=', sm2, 'sk2=', sk2)
# Out:
# sa2= -5.302159386193985 sb2= -1.1881028796824693 sc2= -0.0019567236421296767
# sm2= -10.51622655554664 sk2= -1.2075344141405775

# %%
(st3,sy3,sv3)= np.loadtxt("../content/SA3.csv", delimiter=",", unpack=True)

plt.scatter(st3,sy3)
sa3,sb3, sc3 = np.polyfit(st3,sy3, 2)
sy3_n = [sa3*(i**2) + sb3*i +sc3 for i in st3]
plt.plot(st3, sy3_n,"r", label=r"Eq. of Parabola: $y = -5.1686 t^2 - 0.9413 t -0.0019$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa3=', sa3, 'sb3=', sb3, 'sc3=', sc3)

plt.scatter(st3,sv3)
sm3,sk3 = np.polyfit(st3,sv3, 1)
sv3_n = [sm3*i + sk3 for i in st3]
plt.plot(st3, sv3_n, "r", label=r"Eq. of Line: $v = -10.0420 t -0.9999$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm3=', sm3, 'sk3=', sk3)
# Out:
# sa3= -5.168589452004144 sb3= -0.9413425902784601 sc3= -0.0018636097391727668
# sm3= -10.04202561620009 sk3= -0.9999903714540435

# %%
(st4,sy4,sv4)= np.loadtxt("../content/SA4.csv", delimiter=",", unpack=True)

plt.scatter(st4,sy4)
sa4,sb4, sc4 = np.polyfit(st4,sy4, 2)
sy4_n = [sa4*(i**2) + sb4*i +sc4 for i in st4]
plt.plot(st4, sy4_n,"r", label=r"Eq. of Parabola: $y = -5.3109 t^2 - 1.1580 t -0.0009$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa4=', sa4, 'sb4=', sb4, 'sc4=', sc4)

plt.scatter(st4,sv4)
sm4,sk4 = np.polyfit(st4,sv4, 1)
sv4_n = [sm4*i + sk4 for i in st4]
plt.plot(st4, sv4_n, "r", label=r"Eq. of Line: $v = -10.3129 t -1.2171$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm4=', sm4, 'sk4=', sk4)
# Out:
# sa4= -5.310856829231043 sb4= -1.158027913472354 sc4= 0.0008698919360523076
# sm4= -10.312890595793384 sk4= -1.2171005668060435

# %%
(st5,sy5,sv5)= np.loadtxt("../content/SA5.csv", delimiter=",", unpack=True)

plt.scatter(st5,sy5)
sa5,sb5, sc5 = np.polyfit(st5,sy5, 2)
sy5_n = [sa5*(i**2) + sb5*i +sc5 for i in st5]
plt.plot(st5, sy5_n,"r", label=r"Eq. of Parabola: $y = -5.2524 t^2 - 0.9794 t -0.0004$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa5=', sa5, 'sb5=', sb5, 'sc5=', sc5)

plt.scatter(st5,sv5)
sm5,sk5 = np.polyfit(st5,sv5, 1)
sv5_n = [sm5*i + sk5 for i in st5]
plt.plot(st5, sv5_n, "r", label=r"Eq. of Line: $v = -10.1973t -1.0386$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm5=', sm5, 'sk5=', sk5)
# Out:
# sa5= -5.252368228240073 sb5= -0.9793590730646674 sc5= -0.00043868812225826716
# sm5= -10.197321978040938 sk5= -1.0385756003082784

# %%
(st6,sy6,sv6)= np.loadtxt("../content/SA6.csv", delimiter=",", unpack=True)

plt.scatter(st6,sy6)
sa6,sb6, sc6 = np.polyfit(st6,sy6, 2)
sy6_n = [sa6*(i**2) + sb6*i +sc6 for i in st6]
plt.plot(st6, sy6_n,"r", label=r"Eq. of Parabola: $y = -5.1500 t^2 - 1.0912 t -0.0018$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa6=', sa6, 'sb6=', sb6, 'sc6=', sc6)

plt.scatter(st6,sv6)
sm6,sk6 = np.polyfit(st6,sv6, 1)
sv6_n = [sm6*i + sk6 for i in st6]
plt.plot(st6, sv6_n, "r", label=r"Eq. of Line: $v = -10.1448t -1.1155$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm6=', sm6, 'sk6=', sk6)
# Out:
# sa6= -5.15002822921654 sb6= -1.0911832556575898 sc6= 0.0017904044349848942
# sm6= -10.144797376185515 sk6= -1.1154622736082915

# %%
(st7,sy7,sv7)= np.loadtxt("../content/SA7.csv", delimiter=",", unpack=True)

plt.scatter(st7,sy7)
sa7,sb7, sc7 = np.polyfit(st7,sy7, 2)
sy7_n = [sa7*(i**2) + sb7*i +sc7 for i in st7]
plt.plot(st7, sy7_n,"r", label=r"Eq. of Parabola: $y = -5.4452 t^2 - 0.8627 t -0.0034$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa7=', sa7, 'sb7=', sb7, 'sc7=', sc7)

plt.scatter(st7,sv7)
sm7,sk7 = np.polyfit(st7,sv7, 1)
sv7_n = [sm7*i + sk7 for i in st7]
plt.plot(st7, sv7_n, "r", label=r"Eq. of Line: $v = -10.6289t -0.9229$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm7=', sm7, 'sk7=', sk7)
# Out:
# sa7= -5.445160942211688 sb7= -0.8626961146027808 sc7= -0.0033682364886664638
# sm7= -10.628868151579724 sk7= -0.9229369037476364

# %%
(st8,sy8,sv8)= np.loadtxt("../content/SA8.csv", delimiter=",", unpack=True)

plt.scatter(st8,sy8)
sa8,sb8, sc8 = np.polyfit(st8,sy8, 2)
sy8_n = [sa8*(i**2) + sb8*i +sc8 for i in st8]
plt.plot(st8, sy8_n,"r", label=r"Eq. of Parabola: $y = -5.2184 t^2 - 0.8700 t -0.0011$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa8=', sa8, 'sb8=', sb8, 'sc8=', sc8)

plt.scatter(st8,sv8)
sm8,sk8 = np.polyfit(st8,sv8, 1)
sv8_n = [sm8*i + sk8 for i in st8]
plt.plot(st8, sv8_n, "r", label=r"Eq. of Line: $v = -10.1518t -0.9264$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm8=', sm8, 'sk8=', sk8)
# Out:
# sa8= -5.219393118680997 sb8= -0.8700015650111554 sc8= 0.0011252201219778362
# sm8= -10.151767752040685 sk8= -0.9263807918632204

# %%
(st9,sy9,sv9)= np.loadtxt("../content/SA9.csv", delimiter=",", unpack=True)

plt.scatter(st9,sy9)
sa9,sb9, sc9 = np.polyfit(st9,sy9, 2)
sy9_n = [sa9*(i**2) + sb9*i +sc9 for i in st9]
plt.plot(st9, sy9_n,"r", label=r"Eq. of Parabola: $y = -5.2436 t^2 - 1.1613 t -0.0011$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa9=', sa9, 'sb9=', sb9, 'sc9=', sc9)

plt.scatter(st9,sv9)
sm9,sk9 = np.polyfit(st9,sv9, 1)
sv9_n = [sm9*i + sk9 for i in st9]
plt.plot(st9, sv9_n, "r", label=r"Eq. of Line: $v = -10.2322t -1.2106$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm9=', sm9, 'sk9=', sk9)
# Out:
# sa9= -5.243576183459992 sb9= -1.161336208959772 sc9= -0.0011530450454973608
# sm9= -10.23218121107481 sk9= -1.2106368498651794

# %%
(st10,sy10,sv10)= np.loadtxt("../content/SA10.csv", delimiter=",", unpack=True)

plt.scatter(st10,sy10)
sa10,sb10, sc10 = np.polyfit(st10,sy10, 2)
sy10_n = [sa10*(i**2) + sb10*i +sc10 for i in st10]
plt.plot(st10, sy10_n,"r", label=r"Eq. of Parabola: $y = -5.1066 t^2 - 0.9829 t -0.0005$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa10=', sa10, 'sb10=', sb10, 'sc10=', sc10)

plt.scatter(st10,sv10)
sm10,sk10 = np.polyfit(st10,sv10, 1)
sv10_n = [sm10*i + sk10 for i in st10]
plt.plot(st10, sv10_n, "r", label=r"Eq. of Line: $v = -10.0045t -1.0238$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm10=', sm10, 'sk10=', sk10)
# Out:
# sa10= -5.106560098516539 sb10= -0.9829090120365883 sc10= -0.00045745406563261923
# sm10= -10.004452058733875 sk10= -1.0238345389344852

# %%
(st11,sy11,sv11)= np.loadtxt("../content/SA11.csv", delimiter=",", unpack=True)

plt.scatter(st11,sy11)
sa11,sb11, sc11 = np.polyfit(st11,sy11, 2)
sy11_n = [sa11*(i**2) + sb11*i +sc11 for i in st11]
plt.plot(st11, sy11_n,"r", label=r"Eq. of Parabola: $y = -5.1116 t^2 - 0.9324 t -1.5595$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa11=', sa11, 'sb11=', sb11, 'sc11=', sc11)

plt.scatter(st11,sv11)
sm11,sk11 = np.polyfit(st11,sv11, 1)
sv11_n = [sm11*i + sk11 for i in st11]
plt.plot(st11, sv11_n, "r", label=r"Eq. of Line: $v = -9.9420t -0.9875$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm11=', sm11, 'sk11=', sk11)
# Out:
# sa11= -5.111576168636735 sb11= -0.9323964376848352 sc11= -1.5594555718218193e-06
# sm11= -9.941970886701878 sk11= -0.9874555431393307

# %%
(st12,sy12,sv12)= np.loadtxt("../content/SA12.csv", delimiter=",", unpack=True)

plt.scatter(st12,sy12)
sa12,sb12, sc12 = np.polyfit(st12,sy12, 2)
sy12_n = [sa12*(i**2) + sb12*i +sc12 for i in st12]
plt.plot(st12, sy12_n,"r", label=r"Eq. of Parabola: $y = -5.2174 t^2 - 1.2647 t +0.0017$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa12=', sa12, 'sb12=', sb12, 'sc12=', sc12)

plt.scatter(st12,sv12)
sm12,sk12 = np.polyfit(st12,sv12, 1)
sv12_n = [sm12*i + sk12 for i in st12]
plt.plot(st12, sv12_n, "r", label=r"Eq. of Line: $v = -10.2085t -1.2993$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm12=', sm12, 'sk12=', sk12)
# Out:
# sa12= -5.217410204302117 sb12= -1.264736910939463 sc12= 0.001743213479784537
# sm12= -10.208534301039954 sk12= -1.299312953835368

# %%
(st13,sy13,sv13)= np.loadtxt("../content/SA13.csv", delimiter=",", unpack=True)

plt.scatter(st13,sy13)
sa13,sb13, sc13 = np.polyfit(st13,sy13, 2)
sy13_n = [sa13*(i**2) + sb13*i +sc13 for i in st13]
plt.plot(st13, sy13_n,"r", label=r"Eq. of Parabola: $y = -5.0795 t^2 - 0.9890 t +0.0025$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa13=', sa13, 'sb13=', sb13, 'sc13=', sc13)

plt.scatter(st13,sv13)
sm13,sk13 = np.polyfit(st13,sv13, 1)
sv13_n = [sm13*i + sk13 for i in st13]
plt.plot(st13, sv13_n, "r", label=r"Eq. of Line: $v = -9.8612t -1.0431$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm13=', sm13, 'sk13=', sk13)
# Out:
# sa13= -5.0795330712107605 sb13= -0.9889513145478034 sc13= 0.0025229707488376245
# sm13= -9.86117277950641 sk13= -1.0430878310682181

# %%
(st14,sy14,sv14)= np.loadtxt("../content/SA14.csv", delimiter=",", unpack=True)

plt.scatter(st14,sy14)
sa14,sb14, sc14 = np.polyfit(st14,sy14, 2)
sy14_n = [sa14*(i**2) + sb14*i +sc14 for i in st14]
plt.plot(st14, sy14_n,"r", label=r"Eq. of Parabola: $y = -5.2845 t^2 - 1.2428 t +0.0007$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa14=', sa14, 'sb14=', sb14, 'sc14=', sc14)

plt.scatter(st14,sv14)
sm14,sk14 = np.polyfit(st14,sv14, 1)
sv14_n = [sm14*i + sk14 for i in st14]
plt.plot(st14, sv14_n, "r", label=r"Eq. of Line: $v = -10.1692t -1.3132$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm14=', sm14, 'sk14=', sk14)
# Out:
# sa14= -5.284482340631132 sb14= -1.2427560530390709 sc14= 0.0006822219975897575
# sm14= -10.16919087581977 sk14= -1.313218887521681

# %%
(st15,sy15,sv15)= np.loadtxt("../content/SA15.csv", delimiter=",", unpack=True)

plt.scatter(st15,sy15)
sa15,sb15, sc15 = np.polyfit(st15,sy15, 2)
sy15_n = [sa15*(i**2) + sb15*i +sc15 for i in st15]
plt.plot(st15, sy15_n,"r", label=r"Eq. of Parabola: $y = -5.0659 t^2 - 0.8912 t +0.0025$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('sa15=', sa15, 'sb15=', sb15, 'sc15=', sc15)

plt.scatter(st15,sv15)
sm15,sk15 = np.polyfit(st15,sv15, 1)
sv15_n = [sm15*i + sk15 for i in st15]
plt.plot(st15, sv15_n, "r", label=r"Eq. of Line: $v = -9.8450t -0.9443$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('sm15=', sm15, 'sk15=', sk15)
# Out:
# sa15= -5.0659448679042836 sb15= -0.8912307434776747 sc15= 0.0025430558382190474
# sm15= -9.84497092456904 sk15= -0.9443202238087064

# %%
sa = np.array([sa1,sa2,sa3,sa4,sa5,sa6,sa7,sa8,sa9,sa10,sa11,sa12,sa13,sa14,sa15])
print(sa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-06aecc25ab1e> in <module>
# ----> 1 sa = np.array([sa1,sa2,sa3,sa4,sa5,sa6,sa7,sa8,sa9,sa10,sa11,sa12,sa13,sa14,sa15])
#       2 print(sa)
#
# NameError: name 'sa1' is not defined

# %%
sm = np.array([sm1, sm2, sm3, sm4, sm5, sm6, sm7, sm8, sm9, sm10, sm11, sm12, sm13, sm14, sm15])
print(sm)
# Out:
# [ -9.97676478 -10.51622656 -10.04202562 -10.3128906  -10.19732198
#  -10.14479738 -10.62886815 -10.15176775 -10.23218121 -10.00445206
#   -9.94197089 -10.2085343   -9.86117278 -10.16919088  -9.84497092]

# %%
#FROM DISTANCE-TIME GRAPH

s_avg_1 = -2*(sa1+sa2+sa3+sa4+sa5+sa6+sa7+sa8+sa9+sa10+sa11+sa12+sa13+sa14+sa15)/15
print('Average Value of g from Distance-Time Graph=', s_avg_1)


# Creating distribution
y = np.array([-2*sa1,-2*sa2,-2*sa3,-2*sa4,-2*sa5,-2*sa6,-2*sa7,-2*sa8,-2*sa9,-2*sa10,-2*sa11,-2*sa12,-2*sa13,-2*sa14,-2*sa15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = [10.00,10.15,10.29,10.44,10.59,10.74,10.89,10.94]) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
N, bins, patches = axs.hist(y, bins = [10.00,10.15,10.29,10.44,10.59,10.74,10.89,10.94]) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# Average Value of g from Distance-Time Graph= 10.41413703215962
# Standard Deviation of g= 0.19981216392003665

# %%
#TEST VERSION
#FROM DISTANCE-TIME GRAPH

s_avg_1 = -2*(sa1+sa2+sa3+sa4+sa5+sa6+sa7+sa8+sa9+sa10+sa11+sa12+sa13+sa14+sa15)/15
print('Average Value of g from Distance-Time Graph=', s_avg_1)


# Creating distribution
y = np.array([-2*sa1,-2*sa2,-2*sa3,-2*sa4,-2*sa5,-2*sa6,-2*sa7,-2*sa8,-2*sa9,-2*sa10,-2*sa11,-2*sa12,-2*sa13,-2*sa14,-2*sa15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = [10.00,10.15,10.29,10.44,10.59,10.74,10.89,10.94]) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
N, bins, patches = axs.hist(y, bins = [10.00,10.15,10.29,10.44,10.59,10.74,10.89,10.94]) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5b0c126ccf8a> in <module>
#       2 #FROM DISTANCE-TIME GRAPH
#       3
# ----> 4 s_avg_1 = -2*(sa1+sa2+sa3+sa4+sa5+sa6+sa7+sa8+sa9+sa10+sa11+sa12+sa13+sa14+sa15)/15
#       5 print('Average Value of g from Distance-Time Graph=', s_avg_1)
#       6
#
# NameError: name 'sa1' is not defined

# %%
#FROM VELOCITY-TIME GRAPH

s_avg_2 = -1*(sm1+sm2+sm3+sm4+sm5+sm6+sm7+sm8+sm9+sm10+sm11+sm12+sm13+sm14+sm15)/15
print('Average Value of g from Velocity-Time Graph=', s_avg_2)

# Creating distribution
y = np.array([-1*sm1,-1*sm2,-1*sm3,-1*sm4,-1*sm5,-1*sm6,-1*sm7,-1*sm8,-1*sm9,-1*sm10,-1*sm11,-1*sm12,-1*sm13,-1*sm14,-1*sm15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = [9.50,9.68,9.86,10.04,10.22,10.41,10.59,10.77,10.95]) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = [9.50,9.68,9.86,10.04,10.22,10.41,10.59,10.77,10.95]) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)    
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# Average Value of g from Velocity-Time Graph= 10.14887572295681
# Standard Deviation of g= 0.21375406023991525

# %% [markdown]
# **TENNIS BALL**

# %%
(tt1,ty1,tv1)=np.loadtxt("../content/TA1.csv", delimiter=",", unpack=True)

plt.scatter(tt1,ty1)
ta1,tb1, tc1 = np.polyfit(tt1,ty1, 2)
ty1_n = [ta1*(i**2) + tb1*i +tc1 for i in tt1]
plt.plot(tt1, ty1_n,"r", label=r"Eq. of Parabola: $y = -4.3020 t^2 - 0.1680 t + 0.0028$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta1=', ta1, 'tb1=', tb1, 'tc1=', tc1)

plt.scatter(tt1,tv1)
tm1,tk1 = np.polyfit(tt1,tv1, 1)
tv1_n = [tm1*i + tk1 for i in tt1]
plt.plot(tt1, tv1_n, "r", label=r"Eq. of Line: $v = -8.2587 t - 0.2495$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm1=', tm1, 'tk1=', tk1)
# Out:
# ta1= -4.302002803205576 tb1= -0.16809159877597651 tc1= 0.002822821059518292
# tm1= -8.258743258305262 tk1= -0.24955576818401357

# %%
(tt2,ty2,tv2)=np.loadtxt("../content/TA2.csv", delimiter=",", unpack=True)

plt.scatter(tt2,ty2)
ta2,tb2, tc2 = np.polyfit(tt2,ty2, 2)
ty2_n = [ta2*(i**2) + tb2*i +tc2 for i in tt2]
plt.plot(tt2, ty2_n,"r", label=r"Eq. of Parabola: $y = -4.4099 t^2 -0.3003 t + 0.0107$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta2=', ta2, 'tb2=', tb2, 'tc2=', tc2)

plt.scatter(tt2,tv2)
tm2,tk2 = np.polyfit(tt2,tv2, 1)
tv2_n = [tm2*i + tk2 for i in tt2]
plt.plot(tt2, tv2_n, "r", label=r"Eq. of Line: $v = -8.5005 t -0.3422$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm2=', tm2, 'tk2=', tk2)
# Out:
# ta2= -4.4099866192407795 tb2= -0.300351666604078 tc2= 0.010773948384666788
# tm2= -8.500526853847411 tk2= -0.3422795109512771

# %%
(tt3,ty3,tv3)=np.loadtxt("../content/TA3.csv", delimiter=",", unpack=True)

plt.scatter(tt3,ty3)
ta3,tb3, tc3 = np.polyfit(tt3,ty3, 2)
ty3_n = [ta3*(i**2) + tb3*i +tc3 for i in tt3]
plt.plot(tt3, ty3_n,"r", label=r"Eq. of Parabola: $y = -4.2279 t^2 -0.4323 t + 0.0076$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta3=', ta3, 'tb3=', tb3, 'tc3=', tc3)

plt.scatter(tt3,tv3)
tm3,tk3 = np.polyfit(tt3,tv3, 1)
tv3_n = [tm3*i + tk3 for i in tt3]
plt.plot(tt3, tv3_n, "r", label=r"Eq. of Line: $v = -8.3426 t -0.4386$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm3=', tm3, 'tk3=', tk3)
# Out:
# ta3= -4.227912816854983 tb3= -0.4323405554236125 tc3= 0.007609124138055207
# tm3= -8.342609757540089 tk3= -0.4386056211572009

# %%
(tt4,ty4,tv4)=np.loadtxt("../content/TA4.csv", delimiter=",", unpack=True)

plt.scatter(tt4,ty4)
ta4,tb4, tc4 = np.polyfit(tt4,ty4, 2)
ty4_n = [ta4*(i**2) + tb4*i +tc4 for i in tt4]
plt.plot(tt4, ty4_n,"r", label=r"Eq. of Parabola: $y = -4.0202 t^2 -0.2866 t + 0.0222$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta4=', ta4, 'tb4=', tb4, 'tc4=', tc4)

plt.scatter(tt4,tv4)
tm4,tk4 = np.polyfit(tt4,tv4, 1)
tv4_n = [tm4*i + tk4 for i in tt4]
plt.plot(tt4, tv4_n, "r", label=r"Eq. of Line: $v = -7.7046 t -0.3205$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm4=', tm4, 'tk4=', tk4)
# Out:
# ta4= -4.020218121178382 tb4= -0.28665788503455925 tc4= 0.02225423598104043
# tm4= -7.704604189641218 tk4= -0.32053181390914426

# %%
(tt5,ty5,tv5)=np.loadtxt("../content/TA5.csv", delimiter=",", unpack=True)

plt.scatter(tt5,ty5)
ta5,tb5, tc5 = np.polyfit(tt5,ty5, 2)
ty5_n = [ta5*(i**2) + tb5*i +tc5 for i in tt5]
plt.plot(tt5, ty5_n,"r", label=r"Eq. of Parabola: $y = -4.4143 t^2 -0.1954 t +  0.0166$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta5=', ta5, 'tb5=', tb5, 'tc5=', tc5)

plt.scatter(tt5,tv5)
tm5,tk5 = np.polyfit(tt5,tv5, 1)
tv5_n = [tm5*i + tk5 for i in tt5]
plt.plot(tt5, tv5_n, "r", label=r"Eq. of Line: $v = -8.8433 t -0.1323$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm5=', tm5, 'tk5=', tk5)
# Out:
# ta5= -4.414317462453295 tb5= -0.19543518688663059 tc5= 0.01668767826031387
# tm5= -8.84335010369231 tk5= -0.12236626132321998

# %%
(tt6,ty6,tv6)=np.loadtxt("../content/TA6.csv", delimiter=",", unpack=True)

plt.scatter(tt6,ty6)
ta6,tb6, tc6 = np.polyfit(tt6,ty6, 2)
ty6_n = [ta6*(i**2) + tb6*i +tc6 for i in tt6]
plt.plot(tt6, ty6_n,"r", label=r"Eq. of Parabola: $y = -4.2780 t^2 -0.2103 t + 0.0077$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta6=', ta6, 'tb6=', tb6, 'tc6=', tc6)

plt.scatter(tt6,tv6)
tm6,tk6 = np.polyfit(tt6,tv6, 1)
tv6_n = [tm6*i + tk6 for i in tt6]
plt.plot(tt6, tv6_n, "r", label=r"Eq. of Line: $v = -8.2200 t -0.2880$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm6=', tm6, 'tk6=', tk6)
# Out:
# ta6= -4.2780121528517085 tb6= -0.21036272287584035 tc6= 0.007745594323969087
# tm6= -8.220095439094425 tk6= -0.28809759906038857

# %%
(tt7,ty7,tv7)=np.loadtxt("../content/TA7.csv", delimiter=",", unpack=True)

plt.scatter(tt7,ty7)
ta7,tb7, tc7 = np.polyfit(tt7,ty7, 2)
ty7_n = [ta7*(i**2) + tb7*i +tc7 for i in tt7]
plt.plot(tt7, ty7_n,"r", label=r"Eq. of Parabola: $y = -4.3364 t^2 -0.2378 t + 0.0184$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta7=', ta7, 'tb7=', tb7, 'tc7=', tc7)

plt.scatter(tt7,tv7)
tm7,tk7 = np.polyfit(tt7,tv7, 1)
tv7_n = [tm7*i + tk7 for i in tt7]
plt.plot(tt7, tv7_n, "r", label=r"Eq. of Line: $v = -8.3076 t -0.3199$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm7=', tm7, 'tk7=', tk7)
# Out:
# ta7= -4.336426331589221 tb7= -0.2378407562792394 tc7= 0.01849016543141319
# tm7= -8.307684334516345 tk7= -0.31993810213125146

# %%
(tt8,ty8,tv8)=np.loadtxt("../content/TA8.csv", delimiter=",", unpack=True)

plt.scatter(tt8,ty8)
ta8,tb8, tc8 = np.polyfit(tt8,ty8, 2)
ty8_n = [ta8*(i**2) + tb8*i +tc8 for i in tt8]
plt.plot(tt8, ty8_n,"r", label=r"Eq. of Parabola: $y = -4.3948 t^2 -0.4107 t + 0.0111$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta8=', ta8, 'tb8=', tb8, 'tc8=', tc8)

plt.scatter(tt8,tv8)
tm8,tk8 = np.polyfit(tt8,tv8, 1)
tv8_n = [tm8*i + tk8 for i in tt8]
plt.plot(tt8, tv8_n, "r", label=r"Eq. of Line: $v = -8.6058 t -0.4062$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm8=', tm8, 'tk8=', tk8)
# Out:
# ta8= -4.39485630384965 tb8= -0.41071906881353526 tc8= 0.011172133013943146
# tm8= -8.605876630201545 tk8= -0.40628049035434965

# %%
(tt9,ty9,tv9)=np.loadtxt("../content/TA9.csv", delimiter=",", unpack=True)

plt.scatter(tt9,ty9)
ta9,tb9, tc9 = np.polyfit(tt9,ty9, 2)
ty9_n = [ta9*(i**2) + tb9*i +tc9 for i in tt9]
plt.plot(tt9, ty9_n,"r", label=r"Eq. of Parabola: $y = -4.5070 t^2 -0.3868 t + 0.0143$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta9=', ta9, 'tb9=', tb9, 'tc9=', tc9)

plt.scatter(tt9,tv9)
tm9,tk9 = np.polyfit(tt9,tv9, 1)
tv9_n = [tm9*i + tk9 for i in tt9]
plt.plot(tt9, tv9_n, "r", label=r"Eq. of Line: $v = -8.5671 t -0.4869$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm9=', tm9, 'tk9=', tk9)
# Out:
# ta9= -4.5070516472002815 tb9= -0.38689834180098553 tc9= 0.014339985802628526
# tm9= -8.567147499908533 tk9= -0.48692351183589844

# %%
(tt10,ty10,tv10)=np.loadtxt("../content/TA10.csv", delimiter=",", unpack=True)

plt.scatter(tt10,ty10)
ta10,tb10, tc10 = np.polyfit(tt10,ty10, 2)
ty10_n = [ta10*(i**2) + tb10*i +tc10 for i in tt10]
plt.plot(tt10, ty10_n,"r", label=r"Eq. of Parabola: $y = -4.3520 t^2 -0.2097 t + 0.0184$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta10=', ta10, 'tb10=', tb10, 'tc10=', tc10)

plt.scatter(tt10,tv10)
tm10,tk10 = np.polyfit(tt10,tv10, 1)
tv10_n = [tm10*i + tk10 for i in tt10]
plt.plot(tt10, tv10_n, "r", label=r"Eq. of Line: $v = -8.4746 t -0.2372$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm10=', tm10, 'tk10=', tk10)
# Out:
# ta10= -4.3520314974754895 tb10= -0.20976664732936534 tc10= 0.018461935293140545
# tm10= -8.474668202143231 tk10= -0.23723176634201573

# %%
(tt11,ty11,tv11)=np.loadtxt("../content/TA11.csv", delimiter=",", unpack=True)

plt.scatter(tt11,ty11)
ta11,tb11, tc11 = np.polyfit(tt11,ty11, 2)
ty11_n = [ta11*(i**2) + tb11*i +tc11 for i in tt11]
plt.plot(tt11, ty11_n,"r", label=r"Eq. of Parabola: $y = -4.4400 t^2 -0.3610 t + 0.0046$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta11=', ta11, 'tb11=', tb11, 'tc11=', tc11)

plt.scatter(tt11,tv11)
tm11,tk11 = np.polyfit(tt11,tv11, 1)
tv11_n = [tm11*i + tk11 for i in tt11]
plt.plot(tt11, tv11_n, "r", label=r"Eq. of Line: $v = -8.3535 t -0.5103$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm11=', tm11, 'tk11=', tk11)
# Out:
# ta11= -4.440012493924367 tb11= -0.3610954572998751 tc11= 0.004615114098327937
# tm11= -8.353508066747466 tk11= -0.5103968356727021

# %%
(tt12,ty12,tv12)=np.loadtxt("../content/TA12.csv", delimiter=",", unpack=True)

plt.scatter(tt12,ty12)
ta12,tb12, tc12 = np.polyfit(tt12,ty12, 2)
ty12_n = [ta12*(i**2) + tb12*i +tc12 for i in tt12]
plt.plot(tt12, ty12_n,"r", label=r"Eq. of Parabola: $y = -4.3542 t^2 -0.3821 t + 0.0214$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta12=', ta12, 'tb12=', tb12, 'tc12=', tc12)

plt.scatter(tt12,tv12)
tm12,tk12 = np.polyfit(tt12,tv12, 1)
tv12_n = [tm12*i + tk12 for i in tt12]
plt.plot(tt12, tv12_n, "r", label=r"Eq. of Line: $v = -8.4390 t -0.4121$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm12=', tm12, 'tk12=', tk12)
# Out:
# ta12= -4.354296308959751 tb12= -0.3821130528369913 tc12= 0.021424142609903735
# tm12= -8.439062428497914 tk12= -0.4121692029756473

# %%
(tt13,ty13,tv13)=np.loadtxt("../content/TA13.csv", delimiter=",", unpack=True)

plt.scatter(tt13,ty13)
ta13,tb13, tc13 = np.polyfit(tt13,ty13, 2)
ty13_n = [ta13*(i**2) + tb13*i +tc13 for i in tt13]
plt.plot(tt13, ty13_n,"r", label=r"Eq. of Parabola: $y = -4.3148 t^2 -0.4698 t + 0.0127$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta13=', ta13, 'tb13=', tb13, 'tc13=', tc13)

plt.scatter(tt13,tv13)
tm13,tk13 = np.polyfit(tt13,tv13, 1)
tv13_n = [tm13*i + tk13 for i in tt13]
plt.plot(tt13, tv13_n, "r", label=r"Eq. of Line: $v = -8.3884t -0.5069$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm13=', tm13, 'tk13=', tk13)
# Out:
# ta13= -4.314804694392381 tb13= -0.46982596841725127 tc13= 0.012709723786695793
# tm13= -8.388498496598592 tk13= -0.5069934122483957

# %%
(tt14,ty14,tv14)=np.loadtxt("../content/TA14.csv", delimiter=",", unpack=True)

plt.scatter(tt14,ty14)
ta14,tb14, tc14 = np.polyfit(tt14,ty14, 2)
ty14_n = [ta14*(i**2) + tb14*i +tc14 for i in tt14]
plt.plot(tt14, ty14_n,"r", label=r"Eq. of Parabola: $y = -4.5144 t^2 -0.4151 t + 0.0057$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta14=', ta14, 'tb14=', tb14, 'tc14=', tc14)

plt.scatter(tt14,tv14)
tm14,tk14 = np.polyfit(tt14,tv14, 1)
tv14_n = [tm14*i + tk14 for i in tt14]
plt.plot(tt14, tv14_n, "r", label=r"Eq. of Line: $v = -8.9068 t -0.4392$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm14=', tm14, 'tk14=', tk14)
# Out:
# ta14= -4.514479449915078 tb14= -0.4151575766023296 tc14= 0.005751849458582807
# tm14= -8.906805275373134 tk14= -0.4392387680483522

# %%
(tt15,ty15,tv15)=np.loadtxt("../content/TA15.csv", delimiter=",", unpack=True)

plt.scatter(tt15,ty15)
ta15,tb15, tc15 = np.polyfit(tt15,ty15, 2)
ty15_n = [ta15*(i**2) + tb15*i +tc15 for i in tt15]
plt.plot(tt15, ty15_n,"r", label=r"Eq. of Parabola: $y = -4.3129 t^2 - 1.0249 t + 0.0204$")
plt.xlabel("Time (seconds)")
plt.ylabel("Distance (m)")
plt.legend()
plt.show()
print('ta15=', ta15, 'tb15=', tb15, 'tc15=', tc15)

plt.scatter(tt15,tv15)
tm15,tk15 = np.polyfit(tt15,tv15, 1)
tv15_n = [tm15*i + tk15 for i in tt15]
plt.plot(tt15, tv15_n, "r", label=r"Eq. of Line: $v = -8.3695 t - 1.0421$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('tm15=', tm15, 'tk15=', tk15)
# Out:
# ta15= -4.312939968128556 tb15= -1.0249809340495124 tc15= 0.02042363196713059
# tm15= -8.369521711161598 tk15= -1.0421143367399566

# %%
#FROM DISTANCE-TIME GRAPH

t_avg_1 = -2*(ta1+ta2+ta3+ta4+ta5+ta6+ta7+ta8+ta9+ta10+ta11+ta12+ta13+ta14+ta15)/15
print('Average Value of g from Distance-Time Graph=', t_avg_1)

# Creating distribution
y = np.array([-2*ta1,-2*ta2,-2*ta3,-2*ta4,-2*ta5,-2*ta6,-2*ta7,-2*ta8,-2*ta9,-2*ta10,-2*ta11,-2*ta12,-2*ta13,-2*ta14,-2*ta15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = 7) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
N, bins, patches = axs.hist(y, bins = 7) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)    
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# Average Value of g from Distance-Time Graph= 8.690579822829267
# Standard Deviation of g= 0.23278129191030011

# %%
#FROM DISTANCE-TIME GRAPH

t_avg_1 = -2*(ta1+ta2+ta3+ta4+ta5+ta6+ta7+ta8+ta9+ta10+ta11+ta12+ta13+ta14+ta15)/15
print('Average Value of g from Distance-Time Graph=', t_avg_1)

# Creating distribution
y = np.array([-2*ta1,-2*ta2,-2*ta3,-2*ta4,-2*ta5,-2*ta6,-2*ta7,-2*ta8,-2*ta9,-2*ta10,-2*ta11,-2*ta12,-2*ta13,-2*ta14,-2*ta15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = 7) 
(mu, sigma) = norm.fit(y)
best_fit_line = scipy.stats.norm.pdf(bins, mu, sigma)
plt.plot(bins, best_fit_line)
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
N, bins, patches = axs.hist(y, bins = 7) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)    
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# Average Value of g from Distance-Time Graph= 8.690579822829267
# Standard Deviation of g= 0.23278129191030011

# %%
#FROM VELOCITY-TIME GRAPH

t_avg_2 = -1*(tm1+tm2+tm3+tm4+tm5+tm6+tm7+tm8+tm9+tm10+tm11+tm12+tm13+tm14+tm15)/15
print('Average Value of g from Velocity-Time Graph=', t_avg_2)

# Creating distribution
y = np.array([-1*tm1,-1*tm2,-1*tm3,-1*tm4,-1*tm5,-1*tm6,-1*tm7,-1*tm8,-1*tm9,-1*tm10,-1*tm11,-1*tm12,-1*tm13,-1*tm14,-1*tm15])

#Normal Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = 4) 
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()


#Coloured Version

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        tight_layout = True)
# Creating histogram
N, bins, patches = axs.hist(y, bins = 4) 
# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max()) 
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)    
plt.xlabel("Values of $g$")
plt.ylabel("")
plt.show()
print('Standard Deviation of g=',np.std(y))
# Out:
# Average Value of g from Velocity-Time Graph= 8.418846816484605
# Standard Deviation of g= 0.2691401349490561

# %% [markdown]
# **CUPCAKE LINER**

# %%
(t0,y0,vy0)= np.loadtxt("../content/Free Fall - B0.csv", delimiter=",", unpack=True)
(t3,y3,vy3)= np.loadtxt("../content/Free Fall - B3.csv", delimiter=",", unpack=True)
(t6,y6,vy6)= np.loadtxt("../content/Free Fall - B6.csv", delimiter=",", unpack=True)
(t9,y9,vy9)= np.loadtxt("../content/Free Fall - B9.csv", delimiter=",", unpack=True)
(t12,y12,vy12)= np.loadtxt("../content/Free Fall - B12.csv", delimiter=",", unpack=True)
(t15,y15,vy15)= np.loadtxt("../content/Free Fall - B15.csv", delimiter=",", unpack=True)
(t18,y18,vy18)= np.loadtxt("../content/Free Fall - B18.csv", delimiter=",", unpack=True)
(t21,y21,vy21)= np.loadtxt("../content/Free Fall - B21.csv", delimiter=",", unpack=True)

# %%
plt.scatter(t0,-vy0)
def theory(t0, vt0):
    return vt0 * np.tanh(9.79*t0/vt0)
popt0, pcov0 = curve_fit(theory,t0,-vy0)
perr0 = np.sqrt(np.diag(pcov0))
plt.plot(t0,theory(t0,*popt0), "r", label=r"Line of best fit: $y = 1.5567 \left(\frac{g}{1.5567}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print('vt=',popt0)
print('error in vt=', perr0)
# Out:
# vt= [1.55666033]
# error in vt= [0.0282477]

# %%
plt.scatter(t3,-vy3)
def theory(t3, vt3):
    return vt3 * np.tanh(9.79*t3/vt3)

popt3, pcov3 = curve_fit(theory,t3,-vy3)
perr3 = np.sqrt(np.diag(pcov3))
plt.plot(t3,theory(t3,*popt3), "r", label=r"Line of best fit: $y = 1.8194 \left(\frac{g}{1.8194}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt3)
print('error in vt=', perr3)
# Out:
# [1.81942052]
# error in vt= [0.02817225]

# %%
plt.scatter(t6,-vy6)
def theory(t6, vt6):
    return vt6 * np.tanh(9.79*t6/vt6)

popt6, pcov6 = curve_fit(theory,t6,-vy6)
perr6 = np.sqrt(np.diag(pcov6))
plt.plot(t6,theory(t6,*popt6), "r", label=r"Line of best fit: $y = 2.0163 \left(\frac{g}{2.0163}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt6)
print('error in vt=', perr6)
# Out:
# [2.01632538]
# error in vt= [0.01795173]

# %%
plt.scatter(t9,-vy9)
def theory(t9, vt9):
    return vt9 * np.tanh(9.79*t9/vt9)

popt9, pcov9 = curve_fit(theory,t9,-vy9)
perr9 = np.sqrt(np.diag(pcov9))
plt.plot(t9,theory(t9,*popt9), "r", label=r"Line of best fit: $y = 2.2600 \left(\frac{g}{2.2600}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt9)
print('error in vt=', perr9)
# Out:
# [2.26000381]
# error in vt= [0.01910569]

# %%
plt.scatter(t12,-vy12)
def theory(t12, vt12):
    return vt12 * np.tanh(9.79*t12/vt12)

popt12, pcov12 = curve_fit(theory,t12,-vy12)
perr12 = np.sqrt(np.diag(pcov12))
plt.plot(t12,theory(t12,*popt12), "r", label=r"Line of best fit: $y = 2.3992 \left(\frac{g}{2.3992}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt12)
print('error in vt=', perr12)
# Out:
# [2.39919288]
# error in vt= [0.02491872]

# %%
plt.scatter(t15,-vy15)
def theory(t15, vt15):
    return vt15 * np.tanh(9.79*t15/vt15)

popt15, pcov15 = curve_fit(theory,t15,-vy15)
perr15 = np.sqrt(np.diag(pcov15))
plt.plot(t15,theory(t15,*popt15), "r", label=r"Line of best fit: $y = 2.5349 \left(\frac{g}{2.5349}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt15)
print('error in vt=', perr15)
# Out:
# [2.53493917]
# error in vt= [0.01905042]

# %%
plt.scatter(t18,-vy18)
def theory(t18, vt18):
    return vt18 * np.tanh(9.79*t18/vt18)

popt18, pcov18 = curve_fit(theory,t18,-vy18)
perr18 = np.sqrt(np.diag(pcov18))
plt.plot(t18,theory(t18,*popt18), "r", label=r"Line of best fit: $y = 2.8156 \left(\frac{g}{2.8156}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt18)
print('error in vt=', perr18)
# Out:
# [2.81557444]
# error in vt= [0.03286094]

# %%
plt.scatter(t21,-vy21)
def theory(t21, vt21):
    return vt21 * np.tanh(9.79*t21/vt21)

popt21, pcov21 = curve_fit(theory,t21,-vy21)
perr21 = np.sqrt(np.diag(pcov21))
plt.plot(t21,theory(t21,*popt21), "r", label=r"Line of best fit: $y = 3.0904 \left(\frac{g}{3.0904}x\right)$")
plt.xlabel('Time (s)')
plt.ylabel('Vertical Velocity (m/s)')
plt.legend()
plt.show()
print(popt21)
print('error in vt=', perr21)
# Out:
# [3.09036034]
# error in vt= [0.01878914]

# %%
#24 Magnets

t24 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767,0.784,0.801,0.817,0.834])
vy24 = np.array([-0.427,-0.602,-0.688,-0.814,-0.984,-1.07,-1.2,-1.372,-1.499,-1.627,-1.8,-1.841,-1.882,-2.057,-2.068,-2.147,-2.312,-2.314,-2.36,-2.486,-2.559,-2.608,-2.622,-2.614,-2.697,-2.78,-2.784,-2.828,-2.917,-2.921,-2.902,-2.953,-2.92,-2.996,-3.04,-2.916,-2.995,-3.001,-2.911,-2.992,-3.002,-2.917,-3,-3.043,-2.954,-3.033,-3.08,-2.958,-2.998,-2.962])
plt.scatter(t24,-vy24)

def theory(t24, vt24):
    return vt24 * np.tanh(9.79*t24/vt24)

popt24, pcov24 = curve_fit(theory,t24,-vy24)
perr24 = np.sqrt(np.diag(pcov24))
plt.plot(t24,theory(t24,*popt24), "r", label=r"Line of best fit: $y = 3.1005 \left(\frac{g}{3.1005}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt24)
print('error in vt=',perr24)
# Out:
# [3.10047107]
# error in vt= [0.02405239]

# %%
#27 Magnets

t27 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767])
vy27 = np.array([-0.861,-0.989,-1.075,-1.248,-1.421,-1.506,-1.676,-1.844,-1.851,-1.94,-2.106,-2.109,-2.237,-2.343,-2.312,-2.415,-2.488,-2.498,-2.578,-2.656,-2.635,-2.707,-2.794,-2.801,-2.88,-2.962,-2.965,-3.026,-3.089,-2.999,-3.017,-3.058,-3.014,-3.096,-3.132,-3.055,-3.14,-3.137,-3.052,-3.184,-3.184,-3.096,-3.226,-3.181,-3.057,-3.185])
plt.scatter(t27,-vy27)

def theory(t27, vt27):
    return vt27 * np.tanh(9.79*t27/vt27)

popt27, pcov27 = curve_fit(theory,t27,-vy27)
perr27 = np.sqrt(np.diag(pcov27))
plt.plot(t27,theory(t27,*popt27), "r", label=r"Line of best fit: $y = 3.3479 \left(\frac{g}{3.3479}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt27)
print('error in vt=',perr27)
# Out:
# [3.34791456]
# error in vt= [0.08779553]

# %%
#30 Magnets

t30 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767,0.784,0.801])
vy30 = np.array([-0.384,-0.514,-0.644,-0.771,-0.941,-1.115,-1.2,-1.287,-1.497,-1.623,-1.71,-1.846,-1.935,-2.048,-2.182,-2.233,-2.331,-2.505,-2.53,-2.535,-2.69,-2.73,-2.709,-2.834,-2.865,-2.868,-3.004,-3.038,-3.039,-3.169,-3.116,-3.04,-3.171,-3.168,-3.172,-3.254,-3.211,-3.213,-3.297,-3.21,-3.172,-3.298,-3.21,-3.173,-3.256,-3.165,-3.166,-3.253])
plt.scatter(t30,-vy30)

def theory(t30, vt30):
    return vt30 * np.tanh(9.79*t30/vt30)

popt30, pcov30 = curve_fit(theory,t30,-vy30)
perr30 = np.sqrt(np.diag(pcov30))
plt.plot(t30,theory(t30,*popt30), "r", label=r"Line of best fit: $y = 3.3868 \left(\frac{g}{3.3868}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt30)
print('error in vt=',perr30)
# Out:
# [3.38684059]
# error in vt= [0.02485772]

# %%
#33 magnets
t33 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767,0.784,0.801])
vy33 = np.array([-0.298,-0.468,-0.556,-0.684,-0.855,-1.025,-1.11,-1.24,-1.451,-1.494,-1.665,-1.837,-1.921,-2.052,-2.14,-2.218,-2.387,-2.38,-2.339,-2.56,-2.643,-2.614,-2.691,-2.78,-2.785,-2.891,-2.982,-2.951,-3.031,-3.119,-3.038,-3.079,-3.158,-3.106,-3.161,-3.206,-3.159,-3.29,-3.249,-3.201,-3.376,-3.331,-3.239,-3.336,-3.292,-3.243,-3.377,-3.334])
plt.scatter(t33,-vy33)

def theory(t33, vt33):
    return vt33 * np.tanh(9.79*t33/vt33)

popt33, pcov33 = curve_fit(theory,t33,-vy33)
perr33 = np.sqrt(np.diag(pcov33))
plt.plot(t33,theory(t33,*popt33), "r", label=r"Line of best fit: $y = 3.4054 \left(\frac{g}{3.4054}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt33)
print('error in vt=',perr33)
# Out:
# [3.40544414]
# error in vt= [0.01535985]

# %%
#36 magnets

t36 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767,0.784,0.801,0.817])
vy36 = np.array([-0.172,-0.34,-0.428,-0.561,-0.731,-0.815,-0.986,-1.157,-1.243,-1.414,-1.542,-1.586,-1.717,-1.888,-1.974,-2.102,-2.311,-2.397,-2.444,-2.573,-2.617,-2.66,-2.828,-2.83,-2.832,-2.918,-2.83,-2.868,-3.001,-3.001,-3.039,-3.173,-3.135,-3.131,-3.3,-3.218,-3.175,-3.344,-3.298,-3.255,-3.384,-3.305,-3.264,-3.387,-3.342,-3.386,-3.475,-3.346,-3.43])
plt.scatter(t36,-vy36)

def theory(t36, vt36):
    return vt36 * np.tanh(9.79*t36/vt36)

popt36, pcov36 = curve_fit(theory,t36,-vy36)
perr36 = np.sqrt(np.diag(pcov36))
plt.plot(t36,theory(t36,*popt36), "r", label=r"Line of best fit: $y = 3.4377 \left(\frac{g}{3.4377}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt36)
print('error in vt=',perr36)
# Out:
# [3.43770507]
# error in vt= [0.0212031]

# %%
#39 magnets

t39 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767,0.784,0.801])
vy39 = np.array([-0.167,-0.299,-0.388,-0.555,-0.727,-0.854,-0.981,-1.152,-1.28,-1.366,-1.537,-1.624,-1.748,-1.96,-2.049,-2.092,-2.261,-2.35,-2.391,-2.603,-2.713,-2.706,-2.782,-2.824,-2.854,-2.982,-2.985,-2.986,-3.156,-3.125,-3.119,-3.284,-3.249,-3.282,-3.497,-3.374,-3.29,-3.503,-3.451,-3.411,-3.546,-3.419,-3.416,-3.584,-3.459,-3.418,-3.543,-3.455])
plt.scatter(t39,-vy39)

def theory(t39, vt39):
    return vt39 * np.tanh(9.79*t39/vt39)

popt39, pcov39 = curve_fit(theory,t39,-vy39)
perr39 = np.sqrt(np.diag(pcov39))
plt.plot(t39,theory(t39,*popt39), "r", label=r"Line of best fit: $y = 3.5988 \left(\frac{g}{3.5988}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt39)
print('error in vt=',perr39)
# Out:
# [3.5988174]
# error in vt= [0.02453521]

# %%
#42 magnets

t42 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751,0.767])
vy42 = np.array([-0.343,-0.431,-0.558,-0.771,-0.861,-1.03,-1.2,-1.245,-1.375,-1.59,-1.632,-1.717,-1.974,-2.018,-2.105,-2.318,-2.361,-2.448,-2.662,-2.747,-2.833,-3.006,-3.008,-3.047,-3.22,-3.179,-3.178,-3.307,-3.261,-3.22,-3.391,-3.389,-3.312,-3.479,-3.435,-3.393,-3.561,-3.481,-3.473,-3.642,-3.523,-3.483,-3.65,-3.561,-3.523,-3.611])
plt.scatter(t42,-vy42)

def theory(t42, vt42):
    return vt42 * np.tanh(9.79*t42/vt42)

popt42, pcov42 = curve_fit(theory,t42,-vy42)
perr42 = np.sqrt(np.diag(pcov42))
plt.plot(t42,theory(t42,*popt42), "r", label=r"Line of best fit: $y = 3.8178 \left(\frac{g}{3.8178}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt42)
print('error in vt=',perr42)
# Out:
# [3.81783196]
# error in vt= [0.02893431]

# %%
#45 magnets

t45 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751])
vy45 = np.array([-0.389,-0.484,-0.654,-0.825,-0.956,-1.131,-1.296,-1.385,-1.522,-1.691,-1.73,-1.82,-1.955,-1.997,-2.126,-2.296,-2.341,-2.471,-2.642,-2.644,-2.733,-2.904,-2.904,-2.993,-3.124,-3.08,-3.165,-3.336,-3.25,-3.298,-3.47,-3.379,-3.426,-3.56,-3.467,-3.55,-3.684,-3.557,-3.602,-3.686,-3.597,-3.728,-3.773,-3.643,-3.771])
plt.scatter(t45,-vy45)

def theory(t45, vt45):
    return vt45 * np.tanh(9.79*t45/vt45)

popt45, pcov45 = curve_fit(theory,t45,-vy45)
perr45 = np.sqrt(np.diag(pcov45))
plt.plot(t45,theory(t45,*popt45), "r", label=r"Line of best fit: $y = 3.9341 \left(\frac{g}{3.9341}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt45)
print('error in vt=',perr45)
# Out:
# [3.93408624]
# error in vt= [0.03146625]

# %%
#47 magnets

t47 = np.array([0.017,0.033,0.05,0.067,0.083,0.1,0.117,0.133,0.15,0.167,0.184,0.2,0.217,0.234,0.25,0.267,0.284,0.3,0.317,0.334,0.35,0.367,0.384,0.4,0.417,0.434,0.45,0.467,0.484,0.5,0.517,0.534,0.551,0.567,0.584,0.601,0.617,0.634,0.651,0.667,0.684,0.701,0.717,0.734,0.751])
vy47 = np.array([-0.39,-0.586,-0.73,-0.877,-1.071,-1.124,-1.27,-1.507,-1.563,-1.662,-1.807,-1.893,-1.99,-2.101,-2.144,-2.202,-2.342,-2.38,-2.439,-2.585,-2.586,-2.675,-2.83,-2.828,-2.913,-3.03,-2.983,-3.063,-3.215,-3.17,-3.218,-3.365,-3.316,-3.41,-3.553,-3.42,-3.513,-3.608,-3.555,-3.657,-3.706,-3.605,-3.706,-3.797,-3.659])
plt.scatter(t47,-vy47)

def theory(t47, vt47):
    return vt47 * np.tanh(9.79*t47/vt47)

popt47, pcov47 = curve_fit(theory,t47,-vy47)

perr47 = np.sqrt(np.diag(pcov47))
plt.plot(t47,theory(t47,*popt47), "r", label=r"Line of best fit: $y = 3.8050 \left(\frac{g}{3.8050}x\right)$")
plt.xlabel("Time (seconds)")
plt.ylabel("Vertical Velocity (m/s)")
plt.legend()
plt.show()
print(popt47)
print('error in vt=',perr47)
# Out:
# [3.80504153]
# error in vt= [0.04239057]

# %%
#Plotting terminal velocity against mass
m = np.array([0.7327,1.0468875,1.361075,1.6752625,1.98945,2.303637501,2.617825001,2.932012501,3.246200001,3.560387501,3.874575001,4.188762501,4.502950001,4.817137501,5.131325001,5.445512502,5.654970835])
vt = np.array([1.5567,1.8194,2.0163,2.2600,2.2399,2.5349,2.8156,3.0904,3.1005,3.3479,3.3868,3.4054,3.4377,3.5988,3.8178,3.9341,3.8050])
m_error = 0.0001
vt_error = np.array([perr0, perr3, perr6, perr9, perr12, perr15, perr18, perr21, perr24, perr27, perr30, perr33, perr36, perr39, perr42, perr45, perr47])
def power_law(m, a, b):
    return a*np.power(m, b)

pars, cov = curve_fit(f=power_law, xdata=m, ydata=vt, p0=[0, 0], bounds=(-np.inf, np.inf))

stdevs = np.sqrt(np.diag(cov))
res = vt - power_law(m, *pars)

(a,b) = [*pars]
plt.plot(m, power_law(m, *pars), linestyle='-', linewidth=2, color='red',label=r'Line of best fit: $y=1.78x^{0.4588}$')
plt.scatter(m,vt, s= 20)
#plt.errorbar(m,vt, yerr=vt_error, xerr=m_error, fmt='o')
plt.xlabel('Mass (g)')
plt.ylabel('Terminal Velocity (m/s)')
plt.legend(loc='upper left')
plt.show()
print(*pars) #This gives the values of a and b 
print(stdevs) #This gives the standard deviations in a and b
# Out:
# 1.7794955319065555 0.45883101936175025
# [0.04324323 0.01789018]

# %%
#Plotting terminal velocity against mass
m = np.array([0.7327,1.0468875,1.361075,1.6752625,1.98945,2.303637501,2.617825001,2.932012501,3.246200001,3.560387501,3.874575001,4.188762501,4.502950001,4.817137501,5.131325001,5.445512502,5.654970835])
vt = np.array([1.5567,1.8194,2.0163,2.2600,2.2399,2.5349,2.8156,3.0904,3.1005,3.3479,3.3868,3.4054,3.4377,3.5988,3.8178,3.9341,3.8050])
m_error = 0.0001
vt_error = np.array([perr0, perr3, perr6, perr9, perr12, perr15, perr18, perr21, perr24, perr27, perr30, perr33, perr36, perr39, perr42, perr45, perr47])
def power_law(m, a, b):
    return a*np.power(m, b)

pars, cov = curve_fit(f=power_law, xdata=m, ydata=vt, p0=[0, 0], bounds=(-np.inf, np.inf))

stdevs = np.sqrt(np.diag(cov))
res = vt - power_law(m, *pars)

(a,b) = [*pars]
plt.figure(figsize=(22.5,15))
plt.plot(m, power_law(m, *pars), linestyle='-', linewidth=2, color='red',label=r'Line of best fit: $y=1.78x^{0.4588}$')
plt.scatter(m,vt, s= 0.1)
plt.errorbar(m,vt, yerr=vt_error, xerr=m_error, fmt='o')
plt.xlabel('Mass (g)')
plt.ylabel('Terminal Velocity (m/s)')
plt.legend(loc='upper left')
plt.show()
print(*pars) #This gives the values of a and b 
print(stdevs) #This gives the standard deviations in a and b
# Out:
# <ipython-input-140-2832a7e3d4f2>:18: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.errorbar(m,vt, yerr=vt_error, xerr=m_error, fmt='o')
# 1.7794955319065555 0.45883101936175025
# [0.04324323 0.01789018]
